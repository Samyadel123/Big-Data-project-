# %% [markdown]
# # import lib

# %%
import pandas as  pd

# %% [markdown]
# # data loading

# %%
import os 
data_path = "../raw"
Traffic_data_path = os.path.join(data_path, "Traffic.csv") 
Weather_data_path = os.path.join(data_path, "Weather.csv") 

Traffic_df = pd.read_csv(Traffic_data_path)

Weather_df = pd.read_csv(Weather_data_path)
# inspect data shape 
print(Traffic_df.shape , Weather_df.shape)
# Out:
# (5050, 10) (5050, 11)

# %%
# let's clean each dataframe
